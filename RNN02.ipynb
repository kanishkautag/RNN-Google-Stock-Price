# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishkautag/RNN-Google-Stock-Price/blob/main/RNN02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Load the data
dataset_train = pd.read_csv("/content/Google_Stock_Price_Train.csv", thousands=',',
                            dtype={'Date': str, 'Open': float, 'High': float, 'Low': float, 'Close': float, 'Volume': int})
dataset_test = pd.read_csv("/content/Google_Stock_Price_Test.csv", thousands=',',
                           dtype={'Date': str, 'Open': float, 'High': float, 'Low': float, 'Close': float, 'Volume': int})

# Prepare the training data
training_set = dataset_train.iloc[:, 1:2].values  # Using only 'Open' price

# Scale the features
sc = StandardScaler()
training_set_scaled = sc.fit_transform(training_set)

# Prepare sequences
sequence_length = 60
X_train = []
y_train = []
for i in range(sequence_length, len(training_set_scaled)):
    X_train.append(training_set_scaled[i-sequence_length:i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# Build the LSTM model
regressor = Sequential()
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units=1))

# Compile and train the model
regressor.compile(optimizer='adam', loss='mean_squared_error')
history = regressor.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, verbose=1)

# Prepare the test data
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis=0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - sequence_length:].values
inputs = inputs.reshape(-1, 1)
inputs = sc.transform(inputs)

# Create sequences for prediction
X_test = []
for i in range(sequence_length, len(inputs)):
    X_test.append(inputs[i-sequence_length:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Make predictions
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Get the real stock prices
real_stock_price = dataset_test.iloc[:, 1:2].values

# Calculate MAE and RMSE
mae = mean_absolute_error(real_stock_price, predicted_stock_price)
rmse = np.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print(f"MAE: {mae}, RMSE: {rmse}")

# Visualize the results
plt.plot(real_stock_price, color='red', label='Real Google Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# Visualize the training loss
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 34/34 [==============================] - 16s 165ms/step - loss: 0.1448 - val_loss: 0.0862
# Epoch 2/100
# 34/34 [==============================] - 4s 112ms/step - loss: 0.0392 - val_loss: 0.0667
# Epoch 3/100
# 34/34 [==============================] - 6s 188ms/step - loss: 0.0306 - val_loss: 0.0329
# Epoch 4/100
# 34/34 [==============================] - 5s 160ms/step - loss: 0.0325 - val_loss: 0.0803
# Epoch 5/100
# 34/34 [==============================] - 5s 148ms/step - loss: 0.0262 - val_loss: 0.0433
# Epoch 6/100
# 34/34 [==============================] - 6s 182ms/step - loss: 0.0275 - val_loss: 0.0455
# Epoch 7/100
# 34/34 [==============================] - 4s 118ms/step - loss: 0.0283 - val_loss: 0.0139
# Epoch 8/100
# 34/34 [==============================] - 5s 157ms/step - loss: 0.0253 - val_loss: 0.0406
# Epoch 9/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0250 - val_loss: 0.0324
# Epoch 10/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0235 - val_loss: 0.0219
# Epoch 11/100
# 34/34 [==============================] - 5s 159ms/step - loss: 0.0268 - val_loss: 0.0260
# Epoch 12/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0241 - val_loss: 0.0486
# Epoch 13/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0210 - val_loss: 0.0150
# Epoch 14/100
# 34/34 [==============================] - 6s 166ms/step - loss: 0.0242 - val_loss: 0.0097
# Epoch 15/100
# 34/34 [==============================] - 6s 160ms/step - loss: 0.0225 - val_loss: 0.0110
# Epoch 16/100
# 34/34 [==============================] - 4s 117ms/step - loss: 0.0217 - val_loss: 0.0159
# Epoch 17/100
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0209 - val_loss: 0.0122
# Epoch 18/100
# 34/34 [==============================] - 5s 145ms/step - loss: 0.0247 - val_loss: 0.0454
# Epoch 19/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0213 - val_loss: 0.0366
# Epoch 20/100
# 34/34 [==============================] - 4s 116ms/step - loss: 0.0201 - val_loss: 0.0110
# Epoch 21/100
# 34/34 [==============================] - 6s 173ms/step - loss: 0.0184 - val_loss: 0.0080
# Epoch 22/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0197 - val_loss: 0.0285
# Epoch 23/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0207 - val_loss: 0.0350
# Epoch 24/100
# 34/34 [==============================] - 5s 158ms/step - loss: 0.0189 - val_loss: 0.0149
# Epoch 25/100
# 34/34 [==============================] - 4s 116ms/step - loss: 0.0183 - val_loss: 0.0106
# Epoch 26/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0191 - val_loss: 0.0085
# Epoch 27/100
# 34/34 [==============================] - 6s 167ms/step - loss: 0.0185 - val_loss: 0.0124
# Epoch 28/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0174 - val_loss: 0.0457
# Epoch 29/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0186 - val_loss: 0.0073
# Epoch 30/100
# 34/34 [==============================] - 6s 165ms/step - loss: 0.0192 - val_loss: 0.0099
# Epoch 31/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0184 - val_loss: 0.0064
# Epoch 32/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0163 - val_loss: 0.0055
# Epoch 33/100
# 34/34 [==============================] - 5s 155ms/step - loss: 0.0159 - val_loss: 0.0054
# Epoch 34/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0151 - val_loss: 0.0054
# Epoch 35/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0156 - val_loss: 0.0070
# Epoch 36/100
# 34/34 [==============================] - 5s 139ms/step - loss: 0.0144 - val_loss: 0.0157
# Epoch 37/100
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0161 - val_loss: 0.0082
# Epoch 38/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0163 - val_loss: 0.0106
# Epoch 39/100
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0145 - val_loss: 0.0181
# Epoch 40/100
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0176 - val_loss: 0.0410
# Epoch 41/100
# 34/34 [==============================] - 4s 116ms/step - loss: 0.0161 - val_loss: 0.0090
# Epoch 42/100
# 34/34 [==============================] - 4s 126ms/step - loss: 0.0137 - val_loss: 0.0090
# Epoch 43/100
# 34/34 [==============================] - 5s 146ms/step - loss: 0.0150 - val_loss: 0.0107
# Epoch 44/100
# 34/34 [==============================] - 6s 164ms/step - loss: 0.0146 - val_loss: 0.0062
# Epoch 45/100
# 34/34 [==============================] - 5s 151ms/step - loss: 0.0144 - val_loss: 0.0152
# Epoch 46/100
# 34/34 [==============================] - 4s 119ms/step - loss: 0.0156 - val_loss: 0.0061
# Epoch 47/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0144 - val_loss: 0.0043
# Epoch 48/100
# 34/34 [==============================] - 5s 143ms/step - loss: 0.0157 - val_loss: 0.0120
# Epoch 49/100
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0156 - val_loss: 0.0085
# Epoch 50/100
# 34/34 [==============================] - 4s 117ms/step - loss: 0.0134 - val_loss: 0.0111
# Epoch 51/100
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0137 - val_loss: 0.0180
# Epoch 52/100
# 34/34 [==============================] - 5s 142ms/step - loss: 0.0146 - val_loss: 0.0060
# Epoch 53/100
# 34/34 [==============================] - 4s 116ms/step - loss: 0.0122 - val_loss: 0.0052
# Epoch 54/100
# 34/34 [==============================] - 6s 171ms/step - loss: 0.0127 - val_loss: 0.0117
# Epoch 55/100
# 34/34 [==============================] - 5s 149ms/step - loss: 0.0126 - val_loss: 0.0070
# Epoch 56/100
# 34/34 [==============================] - 4s 112ms/step - loss: 0.0110 - val_loss: 0.0105
# Epoch 57/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0140 - val_loss: 0.0108
# Epoch 58/100
# 34/34 [==============================] - 6s 163ms/step - loss: 0.0131 - val_loss: 0.0037
# Epoch 59/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0131 - val_loss: 0.0059
# Epoch 60/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0131 - val_loss: 0.0107
# Epoch 61/100
# 34/34 [==============================] - 5s 162ms/step - loss: 0.0128 - val_loss: 0.0045
# Epoch 62/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0116 - val_loss: 0.0051
# Epoch 63/100
# 34/34 [==============================] - 6s 164ms/step - loss: 0.0130 - val_loss: 0.0236
# Epoch 64/100
# 34/34 [==============================] - 5s 155ms/step - loss: 0.0139 - val_loss: 0.0111
# Epoch 65/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0118 - val_loss: 0.0049
# Epoch 66/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0118 - val_loss: 0.0194
# Epoch 67/100
# 34/34 [==============================] - 5s 160ms/step - loss: 0.0129 - val_loss: 0.0083
# Epoch 68/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0118 - val_loss: 0.0304
# Epoch 69/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0120 - val_loss: 0.0094
# Epoch 70/100
# 34/34 [==============================] - 5s 160ms/step - loss: 0.0117 - val_loss: 0.0051
# Epoch 71/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0131 - val_loss: 0.0105
# Epoch 72/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0127 - val_loss: 0.0039
# Epoch 73/100
# 34/34 [==============================] - 5s 150ms/step - loss: 0.0114 - val_loss: 0.0077
# Epoch 74/100
# 34/34 [==============================] - 4s 121ms/step - loss: 0.0110 - val_loss: 0.0046
# Epoch 75/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0108 - val_loss: 0.0030
# Epoch 76/100
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0126 - val_loss: 0.0029
# Epoch 77/100
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0128 - val_loss: 0.0091
# Epoch 78/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0123 - val_loss: 0.0184
# Epoch 79/100
# 34/34 [==============================] - 4s 128ms/step - loss: 0.0114 - val_loss: 0.0029
# Epoch 80/100
# 34/34 [==============================] - 5s 144ms/step - loss: 0.0118 - val_loss: 0.0086
# Epoch 81/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0103 - val_loss: 0.0175
# Epoch 82/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0104 - val_loss: 0.0067
# Epoch 83/100
# 34/34 [==============================] - 5s 160ms/step - loss: 0.0102 - val_loss: 0.0088
# Epoch 84/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0108 - val_loss: 0.0062
# Epoch 85/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0112 - val_loss: 0.0093
# Epoch 86/100
# 34/34 [==============================] - 6s 163ms/step - loss: 0.0106 - val_loss: 0.0249
# Epoch 87/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.0135 - val_loss: 0.0031
# Epoch 88/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0116 - val_loss: 0.0128
# Epoch 89/100
# 34/34 [==============================] - 5s 161ms/step - loss: 0.0114 - val_loss: 0.0106
# Epoch 90/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0114 - val_loss: 0.0057
# Epoch 91/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0111 - val_loss: 0.0118
# Epoch 92/100
# 34/34 [==============================] - 5s 151ms/step - loss: 0.0103 - val_loss: 0.0181
# Epoch 93/100
# 34/34 [==============================] - 6s 167ms/step - loss: 0.0119 - val_loss: 0.0053
# Epoch 94/100
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0108 - val_loss: 0.0031
# Epoch 95/100
# 34/34 [==============================] - 5s 159ms/step - loss: 0.0103 - val_loss: 0.0149
# Epoch 96/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0099 - val_loss: 0.0124
# Epoch 97/100
# 34/34 [==============================] - 4s 118ms/step - loss: 0.0100 - val_loss: 0.0029
# Epoch 98/100
# 34/34 [==============================] - 5s 151ms/step - loss: 0.0104 - val_loss: 0.0146
# Epoch 99/100
# 34/34 [==============================] - 4s 119ms/step - loss: 0.0103 - val_loss: 0.0046
# Epoch 100/100
# 34/34 [==============================] - 4s 115ms/step - loss: 0.0103 - val_loss: 0.0150
# 1/1 [==============================] - 2s 2s/step
# MAE: 28.089739013671867, RMSE: 29.14485770349158
